# %%
import pandas as pd
import numpy as np
df_trans = pd.read_csv('df_trans.csv')

# %%
df_trans.head()
# Out:
#    customer_id  transaction_month  transaction_day  transaction_amt  \
# 0       855115                  7                3             1500
# 1       997036                  6                6                0
# 2       398237                  5               24             2500
# 3       997036                  6                2                0
# 4       291636                  7               25                0
#
#    merchant_mcc
# 0  Супермаркеты
# 1  Супермаркеты
# 2     Рестораны
# 3  Супермаркеты
# 4  Супермаркеты

# %%
data = df_trans.groupby(['customer_id'], as_index = False).aggregate({'transaction_amt': 'sum','transaction_month':'min'})

# %%
data
# Out:
#        customer_id  transaction_amt  transaction_month
# 0               15          2221000                  5
# 1               73          1149500                  5
# 2               91           423500                  5
# 3              144             5000                  5
# 4              150                0                  6
# ...            ...              ...                ...
# 46943      1098683            30000                  5
# 46944      1099266            17000                  5
# 46945      1099662             9500                  5
# 46946      1099955            70000                  5
# 46947      1103495           120500                  5
#
# [46948 rows x 3 columns]

# %%
data.transaction_month = data.transaction_month - 4

# %%
data.transaction_amt = data.transaction_amt / data.transaction_month

# %%
data
# Out:
#        customer_id  transaction_amt  transaction_month
# 0               15        2221000.0                  1
# 1               73        1149500.0                  1
# 2               91         423500.0                  1
# 3              144           5000.0                  1
# 4              150              0.0                  2
# ...            ...              ...                ...
# 46943      1098683          30000.0                  1
# 46944      1099266          17000.0                  1
# 46945      1099662           9500.0                  1
# 46946      1099955          70000.0                  1
# 46947      1103495         120500.0                  1
#
# [46948 rows x 3 columns]

# %%
data2 = df_trans.groupby(['customer_id','merchant_mcc'], as_index = False).aggregate({'transaction_amt': 'sum','transaction_day':'count'}).rename(columns = {'transaction_amt':'trat','transaction_day':'coun'})

# %%
data2.head(100)
# Out:
#     customer_id  merchant_mcc     trat  coun
# 0            15          8999        0     1
# 1            15    Авиабилеты  1210500     2
# 2            15        Аптеки     8000     4
# 3            15  Дом и ремонт     7500     5
# 4            15     Дьюти-фри     2000     1
# ..          ...           ...      ...   ...
# 95          362          4215      500     1
# 96          362        Аптеки     7500    17
# 97          362  Дом и ремонт    21000     8
# 98          362      Здоровье     4000     1
# 99          362     Каршеринг     4000     7
#
# [100 rows x 4 columns]

# %%
a=data2.loc[(data2.customer_id == 15)] 
a
# Out:
#     customer_id     merchant_mcc     trat  coun
# 0            15             8999        0     1
# 1            15       Авиабилеты  1210500     2
# 2            15           Аптеки     8000     4
# 3            15     Дом и ремонт     7500     5
# 4            15        Дьюти-фри     2000     1
# 5            15            Книги    11500     1
# 6            15          Красота     8500     3
# 7            15           Музыка     1000     4
# 8            15   Одежда и обувь   247500    11
# 9            15            Отели   344500     2
# 10           15  Прочие магазины    14000     2
# 11           15      Развлечения    39000    11
# 12           15        Рестораны    27500     8
# 13           15      Спорттовары    33000     2
# 14           15         Сувениры     2500     2
# 15           15     Супермаркеты   198500    38
# 16           15        Транспорт    15000     1
# 17           15          Фастфуд    50500     2

# %%
a.loc[(a.trat == a.trat.max())].iloc[0]['trat']
# Out:
# 1210500

# %%
id = list(data.customer_id)

# %%
data2
# Out:
#         customer_id      merchant_mcc     trat  k
# 0                15        Авиабилеты  1210500  2
# 1                15            Аптеки     5000  2
# 2                15           Красота     6000  2
# 3                15            Музыка      500  1
# 4                15    Одежда и обувь   163000  8
# ...             ...               ...      ... ..
# 426480      1103495       Развлечения     2000  1
# 426481      1103495  Страховые услуги    31500  1
# 426482      1103495      Супермаркеты     7500  6
# 426483      1103495           Топливо     9500  4
# 426484      1103495           Фастфуд     1000  3
#
# [426485 rows x 4 columns]

# %%
for i in id:
    a=data2.loc[(data2.customer_id == i)] 
    b = a.loc[(a.trat == a.trat.max())].iloc[0]['merchant_mcc']
    data.loc[data.customer_id==i, 'BZ'] = a.loc[(a.trat == a.trat.max())].iloc[0]['merchant_mcc']

# %%
for i in id:
    a=data2.loc[(data2.customer_id == i)] 
    data.loc[data.customer_id==i, 'BC'] = a.loc[(a.coun == a.coun.max())].iloc[0]['merchant_mcc']

# %%
data
# Out:
#        customer_id  transaction_amt  transaction_month              BZ  \
# 0               15        2221000.0                  1      Авиабилеты
# 1               73        1149500.0                  1      Авиабилеты
# 2               91         423500.0                  1    Дом и ремонт
# 3              144           5000.0                  1          Аптеки
# 4              150              0.0                  2    Супермаркеты
# ...            ...              ...                ...             ...
# 46943      1098683          30000.0                  1    Супермаркеты
# 46944      1099266          17000.0                  1         Фастфуд
# 46945      1099662           9500.0                  1    Супермаркеты
# 46946      1099955          70000.0                  1     Спорттовары
# 46947      1103495         120500.0                  1  Одежда и обувь
#
#                    BC
# 0        Супермаркеты
# 1           Каршеринг
# 2        Дом и ремонт
# ...

# %%
data = data.drop ('transaction_month', 1)

# %%
data.to_csv('data.csv', index=False)

# %%
b = a.loc[(a.trat == a.trat.max())].iloc[0]['merchant_mcc']
b
# Out:
# 'Авиабилеты'

# %%
i = 15

a=data2.loc[(data2.customer_id == i)] 
max_trat = a.loc[(a.trat == a.trat.max())]
data.loc[data.customer_id==i, 'BZ'] =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-8ecfcf2706d4> in <module>
#       3 a=data2.loc[(data2.customer_id == i)]
#       4 b = a.loc[(a.trat == a.trat.max())].iloc[0]['merchant_mcc']
# ----> 5 data.loc[data.customer_id==i and data.transaction_amt == b, 'BZ'] = b
#
# c:\users\екатерина\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
b
# Out:
# 'Авиабилеты'

# %%
data.loc[data.merchant_mcc == b]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-1cabb6b88222> in <module>
# ----> 1 data.loc[data.merchant_mcc == b]
#
# c:\users\екатерина\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'merchant_mcc'

# %%
data
# Out:
#        customer_id  transaction_amt  transaction_month
# 0               15        2034500.0                  1
# 1               73         733500.0                  1
# 2               91         129000.0                  1
# 3              144           2000.0                  1
# 4              150              0.0                  2
# ...            ...              ...                ...
# 46544      1098683          24500.0                  1
# 46545      1099266          15000.0                  1
# 46546      1099662           8500.0                  1
# 46547      1099955          60000.0                  1
# 46548      1103495         115000.0                  1
#
# [46549 rows x 3 columns]

# %%
i = 15

a=data2.loc[(data2.customer_id == i)]

# %%
a
# Out:
#     customer_id     merchant_mcc     trat  coun
# 0            15             8999        0     1
# 1            15       Авиабилеты  1210500     2
# 2            15           Аптеки     8000     4
# 3            15     Дом и ремонт     7500     5
# 4            15        Дьюти-фри     2000     1
# 5            15            Книги    11500     1
# 6            15          Красота     8500     3
# 7            15           Музыка     1000     4
# 8            15   Одежда и обувь   247500    11
# 9            15            Отели   344500     2
# 10           15  Прочие магазины    14000     2
# 11           15      Развлечения    39000    11
# 12           15        Рестораны    27500     8
# 13           15      Спорттовары    33000     2
# 14           15         Сувениры     2500     2
# 15           15     Супермаркеты   198500    38
# 16           15        Транспорт    15000     1
# 17           15          Фастфуд    50500     2

# %%
max_trat = a.loc[(a.trat == a.trat.max())]
b
# Out:
# 1210500

# %%
mcc_max_trat = a.loc[a.customer_id==i and a.trat == b].iloc[0]['merchant_mcc']
mcc_max_trat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-f58872fba085> in <module>
# ----> 1 mcc_max_trat = a.loc[a.customer_id==i and a.trat == b].iloc[0]['merchant_mcc']
#       2 mcc_max_trat
#
# c:\users\екатерина\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
a.loc[(a.trat == a.trat.max())].iloc[0]['merchant_mcc']
# Out:
# 'Авиабилеты'

# %%
max_trat.iloc[0]['merchant_mcc']
# Out:
# 'Авиабилеты'

# %%
df = data.copy(deep=True)

# %%
df
# Out:
#        customer_id  transaction_amt  transaction_month
# 0               15        2221000.0                  1
# 1               73        1149500.0                  1
# 2               91         423500.0                  1
# 3              144           5000.0                  1
# 4              150              0.0                  2
# ...            ...              ...                ...
# 46943      1098683          30000.0                  1
# 46944      1099266          17000.0                  1
# 46945      1099662           9500.0                  1
# 46946      1099955          70000.0                  1
# 46947      1103495         120500.0                  1
#
# [46948 rows x 3 columns]

# %%
data2
# Out:
#         customer_id      merchant_mcc     trat  coun
# 0                15              8999        0     1
# 1                15        Авиабилеты  1210500     2
# 2                15            Аптеки     8000     4
# 3                15      Дом и ремонт     7500     5
# 4                15         Дьюти-фри     2000     1
# ...             ...               ...      ...   ...
# 474110      1103495       Развлечения     2000     1
# 474111      1103495  Страховые услуги    31500     1
# 474112      1103495      Супермаркеты    12500     8
# 474113      1103495           Топливо     9500     4
# 474114      1103495           Фастфуд     1000     3
#
# [474115 rows x 4 columns]

# %%
for i in id:
    a=data2.loc[(data2.customer_id == i)].sort_values('trat', ascending=False ) 
    df.loc[df.customer_id==i, 'BZ1'] = a.iloc[0]['merchant_mcc']
    df.loc[df.customer_id==i, 'BZ2'] = a.iloc[1]['merchant_mcc']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-c85a845cf041> in <module>
#       2     a=data2.loc[(data2.customer_id == i)].sort_values('trat', ascending=False )
#       3     df.loc[df.customer_id==i, 'BZ1'] = a.iloc[0]['merchant_mcc']
# ----> 4     df.loc[df.customer_id==i, 'BZ2'] = a.iloc[1]['merchant_mcc']
#
# c:\users\екатерина\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\users\екатерина\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2155
#    2156             # validate the location
# ...

# %%
i = 15

# %%
a=data2.loc[(data2.customer_id == i)].sort_values('trat', ascending=False )

# %%
ф
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f83b14a9c292> in <module>
# ----> 1 ф
#
# NameError: name 'ф' is not defined

# %%
a
# Out:
#     customer_id     merchant_mcc     trat  coun
# 1            15       Авиабилеты  1210500     2
# 9            15            Отели   344500     2
# 8            15   Одежда и обувь   247500    11
# 15           15     Супермаркеты   198500    38
# 17           15          Фастфуд    50500     2
# 11           15      Развлечения    39000    11
# 13           15      Спорттовары    33000     2
# 12           15        Рестораны    27500     8
# 16           15        Транспорт    15000     1
# 10           15  Прочие магазины    14000     2
# 5            15            Книги    11500     1
# 6            15          Красота     8500     3
# 2            15           Аптеки     8000     4
# 3            15     Дом и ремонт     7500     5
# 14           15         Сувениры     2500     2
# 4            15        Дьюти-фри     2000     1
# 7            15           Музыка     1000     4
# 0            15             8999        0     1

# %%
a=data2.loc[(data2.customer_id == i)].sort_values('trat', ascending=False )

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7d157d7c000a> in <module>
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
a
# Out:
#     customer_id  merchant_mcc  trat  coun
# 66          150  Супермаркеты     0     4

# %%
data2
# Out:
#         customer_id      merchant_mcc     trat  coun
# 0                15              8999        0     1
# 1                15        Авиабилеты  1210500     2
# 2                15            Аптеки     8000     4
# 3                15      Дом и ремонт     7500     5
# 4                15         Дьюти-фри     2000     1
# ...             ...               ...      ...   ...
# 474110      1103495       Развлечения     2000     1
# 474111      1103495  Страховые услуги    31500     1
# 474112      1103495      Супермаркеты    12500     8
# 474113      1103495           Топливо     9500     4
# 474114      1103495           Фастфуд     1000     3
#
# [474115 rows x 4 columns]

# %%
a=data2.loc[(data2.customer_id == i)]

# %%
a
# Out:
#     customer_id  merchant_mcc  trat  coun
# 66          150  Супермаркеты     0     4

# %%
data2.loc[(data2.customer_id == i)]
# Out:
#     customer_id     merchant_mcc     trat  coun
# 0            15             8999        0     1
# 1            15       Авиабилеты  1210500     2
# 2            15           Аптеки     8000     4
# 3            15     Дом и ремонт     7500     5
# 4            15        Дьюти-фри     2000     1
# 5            15            Книги    11500     1
# 6            15          Красота     8500     3
# 7            15           Музыка     1000     4
# 8            15   Одежда и обувь   247500    11
# 9            15            Отели   344500     2
# 10           15  Прочие магазины    14000     2
# 11           15      Развлечения    39000    11
# 12           15        Рестораны    27500     8
# 13           15      Спорттовары    33000     2
# 14           15         Сувениры     2500     2
# 15           15     Супермаркеты   198500    38
# 16           15        Транспорт    15000     1
# 17           15          Фастфуд    50500     2

# %%
data2
# Out:
#         customer_id      merchant_mcc     trat  coun
# 0                15              8999        0     1
# 1                15        Авиабилеты  1210500     2
# 2                15            Аптеки     8000     4
# 3                15      Дом и ремонт     7500     5
# 4                15         Дьюти-фри     2000     1
# ...             ...               ...      ...   ...
# 474110      1103495       Развлечения     2000     1
# 474111      1103495  Страховые услуги    31500     1
# 474112      1103495      Супермаркеты    12500     8
# 474113      1103495           Топливо     9500     4
# 474114      1103495           Фастфуд     1000     3
#
# [474115 rows x 4 columns]

# %%
i = 15

a=data2.loc[(data2.customer_id == i)].sort_values('trat', ascending=False )

# %%
a
# Out:
#     customer_id     merchant_mcc     trat  coun
# 1            15       Авиабилеты  1210500     2
# 9            15            Отели   344500     2
# 8            15   Одежда и обувь   247500    11
# 15           15     Супермаркеты   198500    38
# 17           15          Фастфуд    50500     2
# 11           15      Развлечения    39000    11
# 13           15      Спорттовары    33000     2
# 12           15        Рестораны    27500     8
# 16           15        Транспорт    15000     1
# 10           15  Прочие магазины    14000     2
# 5            15            Книги    11500     1
# 6            15          Красота     8500     3
# 2            15           Аптеки     8000     4
# 3            15     Дом и ремонт     7500     5
# 14           15         Сувениры     2500     2
# 4            15        Дьюти-фри     2000     1
# 7            15           Музыка     1000     4
# 0            15             8999        0     1

# %%
i
# Out:
# 150
